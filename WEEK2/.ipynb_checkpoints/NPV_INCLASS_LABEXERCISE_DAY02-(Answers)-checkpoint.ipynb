# %% [markdown]
# # IN CLASS LAB EXERCISE - 02

# %% [markdown]
# (Kaggle Automobile Dataset)
#
#  We will be using the [automobiles Dataset](https://www.kaggle.com/nisargpatel/automobiles/data) from Kaggle.
#
# **INCLASS LAB EXERCISE** answer below question. Load pandas as pd and upload the Automobile.csv file as auto

# %% [markdown]
# 1. symboling: -3, -2, -1, 0, 1, 2, 3.
# 2. normalized-losses: continuous from 65 to 256.
# 3. make:
# alfa-romero, audi, bmw, chevrolet, dodge, honda,
# isuzu, jaguar, mazda, mercedes-benz, mercury,
# mitsubishi, nissan, peugot, plymouth, porsche,
# renault, saab, subaru, toyota, volkswagen, volvo
#
# 4. fuel-type: diesel, gas.
# 5. aspiration: std, turbo.
# 6. num-of-doors: four, two.
# 7. body-style: hardtop, wagon, sedan, hatchback, convertible.
# 8. drive-wheels: 4wd, fwd, rwd.
# 9. engine-location: front, rear.
# 10. wheel-base: continuous from 86.6 120.9.
# 11. length: continuous from 141.1 to 208.1.
# 12. width: continuous from 60.3 to 72.3.
# 13. height: continuous from 47.8 to 59.8.
# 14. curb-weight: continuous from 1488 to 4066.
# 15. engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
# 16. num-of-cylinders: eight, five, four, six, three, twelve, two.
# 17. engine-size: continuous from 61 to 326.
# 18. fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
# 19. bore: continuous from 2.54 to 3.94.
# 20. stroke: continuous from 2.07 to 4.17.
# 21. compression-ratio: continuous from 7 to 23.
# 22. horsepower: continuous from 48 to 288.
# 23. peak-rpm: continuous from 4150 to 6600.
# 24. city-mpg: continuous from 13 to 49.
# 25. highway-mpg: continuous from 16 to 54.
# 26. price: continuous from 5118 to 45400.

# %% [markdown]
# --------

# %%
import pandas as pd
auto=pd.read_csv("Automobile.csv")
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# **Q.no(1). Check the head of the DataFrame.**

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ------------------

# %% [markdown]
# **Q.no(2). How many rows and columns are there.**

# %%
a=auto.shape
a
# Out:
# (201, 26)

# %% [markdown]
# ---------------------

# %% [markdown]
# **Q.no(3). What is the average Price of all cars in the dataset.**

# %%
import numpy as np
a=np.mean(auto["price"])
a
# Out:
# 13207.129353233831

# %% [markdown]
# -------------------------------

# %% [markdown]
# **Q.no(4). Which is the cheapest make and costliest make of car in the lot.**

# %%
b=auto[auto["price"]==auto["price"].min()]
b["make"].values[0]
# Out:
# 'subaru'

# %%
c=auto[auto["price"]==auto["price"].max()]
c["make"].values[0]
# Out:
# 'mercedes-benz'

# %% [markdown]
# --------------------

# %% [markdown]
# **Q.no(5). How many cars have horsepower greater than 100.**

# %%
d=auto[auto["horsepower"]>100]
d.make.count()
# Out:
# 90

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(6). How many hatchback cars are in the dataset .**

# %%
e=auto[auto["body_style"]=="hatchback"]
e.make.count()
# Out:
# 68

# %% [markdown]
# -------------------

# %% [markdown]
# **Q.no(7). What are the 3 most commonly found cars in the dataset?**

# %%
a=auto["make"].value_counts().head(3)
for i in range(len(a)):
    print(a.index[i])
# Out:
# toyota
# nissan
# mazda

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(8). Someone purchased a car for 7099, what is the make of the car?**

# %%
f=auto[auto["price"]==7099]
f["make"].values[0]
# Out:
# 'nissan'

# %% [markdown]
# -------------

# %% [markdown]
# **Q.no(9). Which cars are priced greater than 40000.**

# %%
g=auto[auto["price"]>40000]
print(g["make"].unique())
# Out:
# ['bmw' 'mercedes-benz']

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(10). Which are the cars that are both a sedan and priced less than 7000?**

# %%
h=auto[(auto["body_style"]=="sedan") & (auto["price"]<7000)]
m=print(h["make"].values)
# Out:
# ['chevrolet' 'dodge' 'isuzu' 'mazda' 'mitsubishi' 'nissan' 'nissan'
#  'nissan' 'plymouth' 'toyota']

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(11) Show the prices of cars in ascending order.**

# %%
m=auto.sort_values(by="price")

print(m[["make","price"]].values)
# Out:
# [['subaru' 5118]
#  ['chevrolet' 5151]
#  ['mazda' 5195]
#  ['toyota' 5348]
#  ['mitsubishi' 5389]
#  ['honda' 5399]
#  ['nissan' 5499]
#  ['plymouth' 5572]
#  ['dodge' 5572]
#  ['mazda' 6095]
#  ['mitsubishi' 6189]
#  ['dodge' 6229]
#  ['plymouth' 6229]
#  ['chevrolet' 6295]
#  ['toyota' 6338]
#  ['dodge' 6377]
#  ['honda' 6479]
#  ['toyota' 6488]
#  ['honda' 6529]
#  ['chevrolet' 6575]
#  ['nissan' 6649]
#  ['mitsubishi' 6669]
#  ['plymouth' 6692]
#  ['dodge' 6692]
#  ['mazda' 6695]
#  ['isuzu' 6785]
#  ['mazda' 6795]
#  ['nissan' 6849]
#  ['honda' 6855]
#  ['toyota' 6918]
#  ['toyota' 6938]
#  ['mitsubishi' 6989]
#  ['subaru' 7053]
#  ['nissan' 7099]
#  ['subaru' 7126]
#  ['honda' 7129]
#  ['toyota' 7198]
#  ['honda' 7295]
#  ['honda' 7295]
#  ['nissan' 7299]
#  ['nissan' 7349]
#  ['mazda' 7395]
#  ['subaru' 7463]
#  ['nissan' 7499]
#  ['subaru' 7603]
#  ['plymouth' 7609]
#  ['dodge' 7609]
#  ['mitsubishi' 7689]
#  ['toyota' 7738]
#  ['volkswagen' 7775]
#  ['subaru' 7775]
#  ['toyota' 7788]
#  ['nissan' 7799]
#  ['honda' 7895]
#  ['toyota' 7898]
#  ['toyota' 7898]
#  ['dodge' 7957]
#  ['plymouth' 7957]
#  ['volkswagen' 7975]
#  ['volkswagen' 7995]
#  ['nissan' 7999]
#  ['subaru' 8013]
#  ['toyota' 8058]
#  ['mitsubishi' 8189]
#  ['volkswagen' 8195]
#  ['toyota' 8238]
#  ['nissan' 8249]
#  ['toyota' 8358]
#  ['toyota' 8449]
#  ['mazda' 8495]
#  ['volkswagen' 8495]
#  ['mitsubishi' 8499]
#  ['dodge' 8558]
#  ['toyota' 8778]
#  ['honda' 8845]
#  ['mazda' 8845]
#  ['dodge' 8921]
#  ['plymouth' 8921]
#  ['toyota' 8948]
#  ['nissan' 8949]
#  ['honda' 9095]
#  ['subaru' 9233]
#  ['toyota' 9258]
#  ['mitsubishi' 9279]
#  ['mitsubishi' 9279]
#  ['renault' 9295]
#  ['toyota' 9298]
#  ['volkswagen' 9495]
#  ['toyota' 9538]
#  ['nissan' 9549]
#  ['toyota' 9639]
#  ['renault' 9895]
#  ['mitsubishi' 9959]
#  ['subaru' 9960]
#  ['volkswagen' 9980]
#  ['toyota' 9988]
#  ['toyota' 9989]
#  ['volkswagen' 9995]
#  ['subaru' 10198]
#  ['mazda' 10245]
#  ['honda' 10295]
#  ['honda' 10345]
#  ['mazda' 10595]
#  ['toyota' 10698]
#  ['mazda' 10795]
#  ['toyota' 10898]
#  ['mazda' 10945]
#  ['isuzu' 11048]
#  ['toyota' 11199]
#  ['mazda' 11245]
#  ['toyota' 11248]
#  ['subaru' 11259]
#  ['toyota' 11549]
#  ['volkswagen' 11595]
#  ['subaru' 11694]
#  ['mazda' 11845]
#  ['saab' 11850]
#  ['peugot' 11900]
#  ['saab' 12170]
#  ['volkswagen' 12290]
#  ['peugot' 12440]
#  ['mitsubishi' 12629]
#  ['plymouth' 12764]
#  ['volvo' 12940]
#  ['honda' 12945]
#  ['dodge' 12964]
#  ['peugot' 13200]
#  ['volkswagen' 13295]
#  ['volvo' 13415]
#  ['alfa-romero' 13495]
#  ['nissan' 13499]
#  ['nissan' 13499]
#  ['mazda' 13645]
#  ['volkswagen' 13845]
#  ['peugot' 13860]
#  ['audi' 13950]
#  ['nissan' 14399]
#  ['mitsubishi' 14489]
#  ['mitsubishi' 14869]
#  ['saab' 15040]
#  ['audi' 15250]
#  ['saab' 15510]
#  ['peugot' 15580]
#  ['mazda' 15645]
#  ['toyota' 15690]
#  ['toyota' 15750]
#  ['volvo' 15985]
#  ['toyota' 15998]
#  ['bmw' 16430]
#  ['alfa-romero' 16500]
#  ['alfa-romero' 16500]
#  ['mercury' 16503]
#  ['volvo' 16515]
#  ['toyota' 16558]
#  ['peugot' 16630]
#  ['peugot' 16695]
#  ['volvo' 16845]
#  ['peugot' 16900]
#  ['bmw' 16925]
#  ['peugot' 17075]
#  ['nissan' 17199]
#  ['audi' 17450]
#  ['toyota' 17669]
#  ['audi' 17710]
#  ['peugot' 17950]
#  ['saab' 18150]
#  ['peugot' 18150]
#  ['mazda' 18280]
#  ['mazda' 18344]
#  ['nissan' 18399]
#  ['volvo' 18420]
#  ['saab' 18620]
#  ['audi' 18920]
#  ['volvo' 18950]
#  ['volvo' 19045]
#  ['nissan' 19699]
#  ['bmw' 20970]
#  ['bmw' 21105]
#  ['volvo' 21485]
#  ['porsche' 22018]
#  ['volvo' 22470]
#  ['volvo' 22625]
#  ['audi' 23875]
#  ['bmw' 24565]
#  ['mercedes-benz' 25552]
#  ['mercedes-benz' 28176]
#  ['mercedes-benz' 28248]
#  ['bmw' 30760]
#  ['mercedes-benz' 31600]
#  ['jaguar' 32250]
#  ['porsche' 32528]
#  ['porsche' 34028]
#  ['mercedes-benz' 34184]
#  ['mercedes-benz' 35056]
#  ['jaguar' 35550]
#  ['jaguar' 36000]
#  ['bmw' 36880]
#  ['porsche' 37028]
#  ['mercedes-benz' 40960]
#  ['bmw' 41315]
#  ['mercedes-benz' 45400]]

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(12).Show the prices of the cars in descending order.**

# %%
n=auto.sort_values(by="price",ascending=False)

print(n[["make","price"]].values)
# Out:
# [['mercedes-benz' 45400]
#  ['bmw' 41315]
#  ['mercedes-benz' 40960]
#  ['porsche' 37028]
#  ['bmw' 36880]
#  ['jaguar' 36000]
#  ['jaguar' 35550]
#  ['mercedes-benz' 35056]
#  ['mercedes-benz' 34184]
#  ['porsche' 34028]
#  ['porsche' 32528]
#  ['jaguar' 32250]
#  ['mercedes-benz' 31600]
#  ['bmw' 30760]
#  ['mercedes-benz' 28248]
#  ['mercedes-benz' 28176]
#  ['mercedes-benz' 25552]
#  ['bmw' 24565]
#  ['audi' 23875]
#  ['volvo' 22625]
#  ['volvo' 22470]
#  ['porsche' 22018]
#  ['volvo' 21485]
#  ['bmw' 21105]
#  ['bmw' 20970]
#  ['nissan' 19699]
#  ['volvo' 19045]
#  ['volvo' 18950]
#  ['audi' 18920]
#  ['saab' 18620]
#  ['volvo' 18420]
#  ['nissan' 18399]
#  ['mazda' 18344]
#  ['mazda' 18280]
#  ['saab' 18150]
#  ['peugot' 18150]
#  ['peugot' 17950]
#  ['audi' 17710]
#  ['toyota' 17669]
#  ['audi' 17450]
#  ['nissan' 17199]
#  ['peugot' 17075]
#  ['bmw' 16925]
#  ['peugot' 16900]
#  ['volvo' 16845]
#  ['peugot' 16695]
#  ['peugot' 16630]
#  ['toyota' 16558]
#  ['volvo' 16515]
#  ['mercury' 16503]
#  ['alfa-romero' 16500]
#  ['alfa-romero' 16500]
#  ['bmw' 16430]
#  ['toyota' 15998]
#  ['volvo' 15985]
#  ['toyota' 15750]
#  ['toyota' 15690]
#  ['mazda' 15645]
#  ['peugot' 15580]
#  ['saab' 15510]
#  ['audi' 15250]
#  ['saab' 15040]
#  ['mitsubishi' 14869]
#  ['mitsubishi' 14489]
#  ['nissan' 14399]
#  ['audi' 13950]
#  ['peugot' 13860]
#  ['volkswagen' 13845]
#  ['mazda' 13645]
#  ['nissan' 13499]
#  ['nissan' 13499]
#  ['alfa-romero' 13495]
#  ['volvo' 13415]
#  ['volkswagen' 13295]
#  ['peugot' 13200]
#  ['dodge' 12964]
#  ['honda' 12945]
#  ['volvo' 12940]
#  ['plymouth' 12764]
#  ['mitsubishi' 12629]
#  ['peugot' 12440]
#  ['volkswagen' 12290]
#  ['saab' 12170]
#  ['peugot' 11900]
#  ['saab' 11850]
#  ['mazda' 11845]
#  ['subaru' 11694]
#  ['volkswagen' 11595]
#  ['toyota' 11549]
#  ['subaru' 11259]
#  ['toyota' 11248]
#  ['mazda' 11245]
#  ['toyota' 11199]
#  ['isuzu' 11048]
#  ['mazda' 10945]
#  ['toyota' 10898]
#  ['mazda' 10795]
#  ['toyota' 10698]
#  ['mazda' 10595]
#  ['honda' 10345]
#  ['honda' 10295]
#  ['mazda' 10245]
#  ['subaru' 10198]
#  ['volkswagen' 9995]
#  ['toyota' 9989]
#  ['toyota' 9988]
#  ['volkswagen' 9980]
#  ['subaru' 9960]
#  ['mitsubishi' 9959]
#  ['renault' 9895]
#  ['toyota' 9639]
#  ['nissan' 9549]
#  ['toyota' 9538]
#  ['volkswagen' 9495]
#  ['toyota' 9298]
#  ['renault' 9295]
#  ['mitsubishi' 9279]
#  ['mitsubishi' 9279]
#  ['toyota' 9258]
#  ['subaru' 9233]
#  ['honda' 9095]
#  ['nissan' 8949]
#  ['toyota' 8948]
#  ['plymouth' 8921]
#  ['dodge' 8921]
#  ['honda' 8845]
#  ['mazda' 8845]
#  ['toyota' 8778]
#  ['dodge' 8558]
#  ['mitsubishi' 8499]
#  ['mazda' 8495]
#  ['volkswagen' 8495]
#  ['toyota' 8449]
#  ['toyota' 8358]
#  ['nissan' 8249]
#  ['toyota' 8238]
#  ['volkswagen' 8195]
#  ['mitsubishi' 8189]
#  ['toyota' 8058]
#  ['subaru' 8013]
#  ['nissan' 7999]
#  ['volkswagen' 7995]
#  ['volkswagen' 7975]
#  ['dodge' 7957]
#  ['plymouth' 7957]
#  ['toyota' 7898]
#  ['toyota' 7898]
#  ['honda' 7895]
#  ['nissan' 7799]
#  ['toyota' 7788]
#  ['subaru' 7775]
#  ['volkswagen' 7775]
#  ['toyota' 7738]
#  ['mitsubishi' 7689]
#  ['plymouth' 7609]
#  ['dodge' 7609]
#  ['subaru' 7603]
#  ['nissan' 7499]
#  ['subaru' 7463]
#  ['mazda' 7395]
#  ['nissan' 7349]
#  ['nissan' 7299]
#  ['honda' 7295]
#  ['honda' 7295]
#  ['toyota' 7198]
#  ['honda' 7129]
#  ['subaru' 7126]
#  ['nissan' 7099]
#  ['subaru' 7053]
#  ['mitsubishi' 6989]
#  ['toyota' 6938]
#  ['toyota' 6918]
#  ['honda' 6855]
#  ['nissan' 6849]
#  ['mazda' 6795]
#  ['isuzu' 6785]
#  ['mazda' 6695]
#  ['dodge' 6692]
#  ['plymouth' 6692]
#  ['mitsubishi' 6669]
#  ['nissan' 6649]
#  ['chevrolet' 6575]
#  ['honda' 6529]
#  ['toyota' 6488]
#  ['honda' 6479]
#  ['dodge' 6377]
#  ['toyota' 6338]
#  ['chevrolet' 6295]
#  ['plymouth' 6229]
#  ['dodge' 6229]
#  ['mitsubishi' 6189]
#  ['mazda' 6095]
#  ['plymouth' 5572]
#  ['dodge' 5572]
#  ['nissan' 5499]
#  ['honda' 5399]
#  ['mitsubishi' 5389]
#  ['toyota' 5348]
#  ['mazda' 5195]
#  ['chevrolet' 5151]
#  ['subaru' 5118]]

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(12).What is the rank order of the cars as per there horsepower.**

# %%
auto["Rank"]=auto["horsepower"].rank(ascending=True)
auto
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# 7            1                168         audi       gas        std
# 8            1                158         audi       gas      turbo
# 9            2                192          bmw       gas        std
# 10           0                192          bmw       gas        std
# 11           0                188          bmw       gas        std
# 12           0                188          bmw       gas        std
# 13           1                149          bmw       gas        std
# 14           0                149          bmw       gas        std
# 15           0                149          bmw       gas        std
# 16           0                149          bmw       gas        std
# 17           2                121    chevrolet       gas        std
# 18           1                 98    chevrolet       gas        std
# 19           0                 81    chevrolet       gas        std
# 20           1                118        dodge       gas        std
# 21           1                118        dodge       gas        std
# 22           1                118        dodge       gas      turbo
# 23           1                148        dodge       gas        std
# 24           1                148        dodge       gas        std
# 25           1                148        dodge       gas        std
# 26           1                148        dodge       gas      turbo
# 27          -1                110        dodge       gas        std
# 28           3                145        dodge       gas      turbo
# 29           2                137        honda       gas        std
# ..         ...                ...          ...       ...        ...
# 171         -1                 65       toyota       gas        std
# 172         -1                 65       toyota       gas        std
# 173         -1                 65       toyota       gas        std
# 174          3                197       toyota       gas        std
# 175          3                197       toyota       gas        std
# 176         -1                 90       toyota       gas        std
# 177         -1                133       toyota       gas        std
# 178          2                122   volkswagen    diesel        std
# 179          2                122   volkswagen       gas        std
# 180          2                 94   volkswagen    diesel        std
# 181          2                 94   volkswagen       gas        std
# 182          2                 94   volkswagen       gas        std
# 183          2                 94   volkswagen    diesel      turbo
# 184          2                 94   volkswagen       gas        std
# 185          3                137   volkswagen       gas        std
# 186          3                256   volkswagen       gas        std
# 187          0                132   volkswagen       gas        std
# 188          0                132   volkswagen    diesel      turbo
# 189          0                132   volkswagen       gas        std
# 190         -2                103        volvo       gas        std
# 191         -1                 74        volvo       gas        std
# 192         -2                103        volvo       gas        std
# 193         -1                 74        volvo       gas        std
# 194         -2                103        volvo       gas      turbo
# 195         -1                 74        volvo       gas      turbo
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# 5               two        sedan          fwd           front        99.8
# 6              four        sedan          fwd           front       105.8
# 7              four        wagon          fwd           front       105.8
# 8              four        sedan          fwd           front       105.8
# 9               two        sedan          rwd           front       101.2
# 10             four        sedan          rwd           front       101.2
# 11              two        sedan          rwd           front       101.2
# 12             four        sedan          rwd           front       101.2
# 13             four        sedan          rwd           front       103.5
# 14             four        sedan          rwd           front       103.5
# 15              two        sedan          rwd           front       103.5
# 16             four        sedan          rwd           front       110.0
# 17              two    hatchback          fwd           front        88.4
# 18              two    hatchback          fwd           front        94.5
# 19             four        sedan          fwd           front        94.5
# 20              two    hatchback          fwd           front        93.7
# 21              two    hatchback          fwd           front        93.7
# 22              two    hatchback          fwd           front        93.7
# 23             four    hatchback          fwd           front        93.7
# 24             four        sedan          fwd           front        93.7
# 25             four        sedan          fwd           front        93.7
# 26              two        sedan          fwd           front        93.7
# 27             four        wagon          fwd           front       103.3
# 28              two    hatchback          fwd           front        95.9
# 29              two    hatchback          fwd           front        86.6
# ..              ...          ...          ...             ...         ...
# 171            four    hatchback          fwd           front       102.4
# 172            four        sedan          fwd           front       102.4
# 173            four    hatchback          fwd           front       102.4
# 174             two    hatchback          rwd           front       102.9
# 175             two    hatchback          rwd           front       102.9
# 176            four        sedan          rwd           front       104.5
# 177            four        wagon          rwd           front       104.5
# 178             two        sedan          fwd           front        97.3
# 179             two        sedan          fwd           front        97.3
# 180            four        sedan          fwd           front        97.3
# 181            four        sedan          fwd           front        97.3
# 182            four        sedan          fwd           front        97.3
# 183            four        sedan          fwd           front        97.3
# 184            four        sedan          fwd           front        97.3
# 185             two  convertible          fwd           front        94.5
# 186             two    hatchback          fwd           front        94.5
# 187            four        sedan          fwd           front       100.4
# 188            four        sedan          fwd           front       100.4
# 189            four        wagon          fwd           front       100.4
# 190            four        sedan          rwd           front       104.3
# 191            four        wagon          rwd           front       104.3
# 192            four        sedan          rwd           front       104.3
# 193            four        wagon          rwd           front       104.3
# 194            four        sedan          rwd           front       104.3
# 195            four        wagon          rwd           front       104.3
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  \
# 0    ...         mpfi  3.47    2.68               9.00        111     5000
# 1    ...         mpfi  3.47    2.68               9.00        111     5000
# 2    ...         mpfi  2.68    3.47               9.00        154     5000
# 3    ...         mpfi  3.19    3.40              10.00        102     5500
# 4    ...         mpfi  3.19    3.40               8.00        115     5500
# 5    ...         mpfi  3.19    3.40               8.50        110     5500
# 6    ...         mpfi  3.19    3.40               8.50        110     5500
# 7    ...         mpfi  3.19    3.40               8.50        110     5500
# 8    ...         mpfi  3.13    3.40               8.30        140     5500
# 9    ...         mpfi  3.50    2.80               8.80        101     5800
# 10   ...         mpfi  3.50    2.80               8.80        101     5800
# 11   ...         mpfi  3.31    3.19               9.00        121     4250
# 12   ...         mpfi  3.31    3.19               9.00        121     4250
# 13   ...         mpfi  3.31    3.19               9.00        121     4250
# 14   ...         mpfi  3.62    3.39               8.00        182     5400
# 15   ...         mpfi  3.62    3.39               8.00        182     5400
# 16   ...         mpfi  3.62    3.39               8.00        182     5400
# 17   ...         2bbl  2.91    3.03               9.50         48     5100
# 18   ...         2bbl  3.03    3.11               9.60         70     5400
# 19   ...         2bbl  3.03    3.11               9.60         70     5400
# 20   ...         2bbl  2.97    3.23               9.41         68     5500
# 21   ...         2bbl  2.97    3.23               9.40         68     5500
# 22   ...         mpfi  3.03    3.39               7.60        102     5500
# 23   ...         2bbl  2.97    3.23               9.40         68     5500
# 24   ...         2bbl  2.97    3.23               9.40         68     5500
# 25   ...         2bbl  2.97    3.23               9.40         68     5500
# 26   ...         mpfi  3.03    3.39               7.60        102     5500
# 27   ...         2bbl  3.34    3.46               8.50         88     5000
# 28   ...          mfi  3.60    3.90               7.00        145     5000
# 29   ...         1bbl  2.91    3.41               9.60         58     4800
# ..   ...          ...   ...     ...                ...        ...      ...
# 171  ...         mpfi  3.31    3.54               8.70         92     4200
# 172  ...         mpfi  3.31    3.54               8.70         92     4200
# 173  ...         mpfi  3.31    3.54               8.70         92     4200
# 174  ...         mpfi  3.27    3.35               9.30        161     5200
# 175  ...         mpfi  3.27    3.35               9.30        161     5200
# 176  ...         mpfi  3.27    3.35               9.20        156     5200
# 177  ...         mpfi  3.27    3.35               9.20        156     5200
# 178  ...          idi  3.01    3.40              23.00         52     4800
# 179  ...         mpfi  3.19    3.40               9.00         85     5250
# 180  ...          idi  3.01    3.40              23.00         52     4800
# 181  ...         mpfi  3.19    3.40               9.00         85     5250
# 182  ...         mpfi  3.19    3.40               9.00         85     5250
# 183  ...          idi  3.01    3.40              23.00         68     4500
# 184  ...         mpfi  3.19    3.40              10.00        100     5500
# 185  ...         mpfi  3.19    3.40               8.50         90     5500
# 186  ...         mpfi  3.19    3.40               8.50         90     5500
# 187  ...         mpfi  3.19    3.40               8.50        110     5500
# 188  ...          idi  3.01    3.40              23.00         68     4500
# 189  ...         mpfi  3.19    3.40               9.00         88     5500
# 190  ...         mpfi  3.78    3.15               9.50        114     5400
# 191  ...         mpfi  3.78    3.15               9.50        114     5400
# 192  ...         mpfi  3.78    3.15               9.50        114     5400
# 193  ...         mpfi  3.78    3.15               9.50        114     5400
# 194  ...         mpfi  3.62    3.15               7.50        162     5100
# 195  ...         mpfi  3.62    3.15               7.50        162     5100
# 196  ...         mpfi  3.78    3.15               9.50        114     5400
# 197  ...         mpfi  3.78    3.15               8.70        160     5300
# 198  ...         mpfi  3.58    2.87               8.80        134     5500
# 199  ...          idi  3.01    3.40              23.00        106     4800
# 200  ...         mpfi  3.78    3.15               9.50        114     5400
#
#      city_mpg highway_mpg  price   Rank
# 0          21          27  13495  133.5
# 1          21          27  16500  133.5
# 2          19          26  16500  175.0
# 3          24          30  13950  120.0
# 4          18          22  17450  144.0
# 5          19          25  15250  127.5
# 6          19          25  17710  127.5
# 7          19          25  18920  127.5
# 8          17          20  23875  164.0
# 9          23          29  16430  114.5
# 10         23          29  16925  114.5
# 11         21          28  20970  156.0
# 12         21          28  21105  156.0
# 13         20          25  24565  156.0
# 14         16          22  30760  193.0
# 15         16          22  41315  193.0
# 16         15          20  36880  193.0
# 17         47          53   5151    1.0
# 18         38          43   6295   49.0
# 19         38          43   6575   49.0
# 20         37          41   5572   25.0
# 21         31          38   6377   25.0
# 22         24          30   7957  120.0
# 23         31          38   6229   25.0
# 24         31          38   6692   25.0
# 25         31          38   7609   25.0
# 26         24          30   8558  120.0
# 27         24          30   8921   83.5
# 28         19          24  12964  169.0
# 29         49          54   6479    7.0
# ..        ...         ...    ...    ...
# 171        27          32   9988   93.5
# 172        27          32  10898   93.5
# 173        27          32  11248   93.5
# 174        20          24  16558  185.5
# 175        19          24  15998  185.5
# 176        20          24  15690  178.5
# 177        19          24  15750  178.5
# 178        37          46   7775    2.5
# 179        27          34   7975   75.0
# 180        37          46   7995    2.5
# 181        27          34   8195   75.0
# 182        27          34   8495   75.0
# 183        37          42   9495   25.0
# 184        26          32   9995  110.5
# 185        24          29  11595   89.0
# 186        24          29   9980   89.0
# 187        19          24  13295  127.5
# 188        33          38  13845   25.0
# 189        25          31  12290   83.5
# 190        23          28  12940  140.5
# 191        23          28  13415  140.5
# 192        24          28  15985  140.5
# 193        24          28  16515  140.5
# 194        17          22  18420  187.5
# 195        17          22  18950  187.5
# 196        23          28  16845  140.5
# 197        19          25  19045  182.0
# 198        18          23  21485  162.0
# 199        26          27  22470  123.0
# 200        19          25  22625  140.5
#
# [201 rows x 27 columns]

# %% [markdown]
# ---------------------

# %% [markdown]
# **Q.no(13).What is the rank order of the cars as per there minimum prices.**

# %%
auto["Rank"]=auto["price"].rank()
auto.head(5)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  city_mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
#
#   highway_mpg  price   Rank
# 0          27  13495  130.0
# 1          27  16500  150.5
# 2          26  16500  150.5
# 3          30  13950  136.0
# 4          22  17450  162.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(14).What is the rank order of the cars as per there maximum prices.**

# %%
auto["Rank"]=auto["price"].rank(ascending=False)
auto.head(5)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  city_mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
#
#   highway_mpg  price  Rank
# 0          27  13495  72.0
# 1          27  16500  51.5
# 2          26  16500  51.5
# 3          30  13950  66.0
# 4          22  17450  40.0
#
# [5 rows x 27 columns]

# %% [markdown]
# -------------

# %% [markdown]
# **Q.no(15).What is the dense rank order of the cars as per there horsepower.**

# %%
auto["Rank"]=auto["horsepower"].rank(ascending=True,method='dense')
auto.head(5)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  city_mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
#
#   highway_mpg  price  Rank
# 0          27  13495  31.0
# 1          27  16500  31.0
# 2          26  16500  46.0
# 3          30  13950  28.0
# 4          22  17450  34.0
#
# [5 rows x 27 columns]

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(16). Write a code to display the  `make` and `price` of `5,6,10` rows.**

# %%
a=auto[["make","price"]]

b=pd.DataFrame(a,index=[5,6,10])
b
# Out:
#     make  price
# 5   audi  15250
# 6   audi  17710
# 10   bmw  16925

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(17). Write a code to display the  `first five columns` and  `5 to 10 rows` using as per `index position`.**

# %%
auto.iloc[5:11,1:6]
# Out:
#     normalized_losses  make fuel_type aspiration number_of_doors
# 5                 161  audi       gas        std             two
# 6                 158  audi       gas        std            four
# 7                 168  audi       gas        std            four
# 8                 158  audi       gas      turbo            four
# 9                 192   bmw       gas        std             two
# 10                192   bmw       gas        std            four

# %% [markdown]
# ------------------------------------

# %% [markdown]
# # ----------------------------------HAPPY LEARNING----------------------------------------

# %% [markdown]
# -------
