# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Since it is a medical dataset so we cannot perform feature selection
#and no replacement of missing data with mean and median

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# No missing data

# %%
sns.scatterplot(df.Pregnancies,df.Outcome)

# %%
plt.figure(figsize=(8,8))
df.boxplot()

# %%
# There are outliers in the dataset, mostly in Insulin column

# %%
sns.scatterplot(x=df.Pregnancies,y=df.Age,hue=df.Outcome)

# %%
# Risk of diabetes increases as women age

# %%
sns.barplot(x=df.Outcome,y=df.Pregnancies)

# %%
sns.barplot(x=df.Outcome,y=df.Age)

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(10,15))
sns.heatmap(data=df.corr(),annot=True)

# %%
sns.kdeplot(df.Age)

# %%
# Age Data right skewed so has positive outliers

# %%
df[df.BloodPressure==0].groupby("Outcome")["Age"].count()
# Out:
# Outcome
# 0    19
# 1    16
# Name: Age, dtype: int64

# %%
df[df.Insulin==0].groupby("Outcome")["Age"].count()
# Out:
# Outcome
# 0    236
# 1    138
# Name: Age, dtype: int64
