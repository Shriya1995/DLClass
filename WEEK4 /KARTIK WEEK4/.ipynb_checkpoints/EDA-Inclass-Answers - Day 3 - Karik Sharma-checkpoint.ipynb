# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#aec101"> Bivariate Analysis

# %% [markdown]
# * Bivariate analysis is a statistical method that helps you study relationships (correlation) between data sets

# %% [markdown]
# ### Quantitative vs. Quantitative
#     1. Scatterplot
#     2. Line plot

# %% [markdown]
# ### Categorical vs. Quantitative
#     1. Bar chart (on summary statistics)
#     2. Grouped kernel density plots
#     3. Box plots
#     4. Violin plots

# %% [markdown]
# ### Categorical vs. Categorical
#     1. Stacked bar chart
#     2. Grouped bar chart
#     3. Segmented bar chart

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#aec101">Case study 1
#     <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#b53f05"> (Titanic Data Set)

# %% [markdown]
# ### Problem Feature:
# The sinking of the Titanic is one of the most infamous shipwrecks in history. **On April 15, 1912**, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing **1502 out of 2224** passengers and crew. That's why the name DieTanic. This is a very unforgetable disaster that no one in the world can forget.
#
# 1.  **Age** ==>> Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# 2. **Sibsp** ==>> The dataset defines family relations in this way...
#
#     a. Sibling = brother, sister, stepbrother, stepsister
#
#     b. Spouse = husband, wife (mistresses and fiancés were ignored)
#
# 3. **Parch** ==>> The dataset defines family relations in this way...
#
#     a. Parent = mother, father
#
#     b. Child = daughter, son, stepdaughter, stepson
#
#     c. Some children travelled only with a nanny, therefore parch=0 for them.
#
# 4. **Pclass** ==>> A proxy for socio-economic status (SES)
#
#     * 1st = Upper
#     * 2nd = Middle
#     * 3rd = Lower
#
# 5. **Embarked** ==>> nominal datatype
# 6. **Name** ==>> nominal datatype . It could be used in feature engineering to derive the gender from title
# 7. **Sex** ==>>  nominal datatype
# 8. **Ticket** ==>> that have no impact on the outcome variable. Thus, they will be excluded from analysis
# 9. **Cabin** ==>>  is a nominal datatype that can be used in feature engineering
# 11. **Fare** ==>>  Indicating the fare
# 12. **PassengerID ** ==>> have no impact on the outcome variable. Thus, it will be excluded from analysis
# 11. **Survival** is ==>> **[dependent variable], 0 or 1

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.1 Loading the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.2 import the dataset ?

# %%
df = pd.read_csv("Titanictrain.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.3 How to see the size of your data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.4 How to view the statistical characteristics of the data?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.5 How to see just one column.describe()?

# %%
df.Pclass.describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.6 How to check the column names?

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.7 Check the Numerical Features,Categorical Features, Alphanumeric Features?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
#     * Categorical: Name, Sex, Ticket, Cabin, Embarked
#     * Numerical Features: PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare
#     * Alphanumeric Features:

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.8 Categorical vs. Quantitative

# %% [markdown]
#     * Categorical: Name, Sex, Ticket, Cabin, Embarked
#     * Numerical Features: PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8a) Create bar plot for showing Sex Vs Survived. And your Observation?

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Survived.groupby(df.Sex).value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
total_m = 577
total_f = 314
sur_m = 109
sur_f = 233
#draw a bar plot of survival by sex

sns.barplot(data=df,x = df.Sex, y = df.Survived, estimator=sum)
#print percentages of females vs. males that survive

per_m = sur_m/total_m*100
per_f = sur_f/total_f*100

print("The percentage of Males Survived are {}".format(per_m))
print("The percentage of Females Survived are {}".format(per_f))
# Out:
# The percentage of Males Survived are 18.890814558058924
# The percentage of Females Survived are 74.20382165605095

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observation:

# %% [markdown]
# It is clear from the above chart that almost 75% females who boraded the ship were able to survive whereas only 18% males were able to survive

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.8d) Create a bar plot Pclass Vs Survived.And your Observation?

# %%
import matplotlib.pyplot as plt

# %%
df.Survived.groupby(df.Pclass).sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
# Create subplot
plt.subplot(1,1,1)
sns.barplot(data=df,x=df.Pclass, y = df.Survived, estimator=sum)

#print percentages of 1st vs. 2nd and 3rd class
total_p1 = 216
total_p2 = 184
total_p3 = 491

sur_1 = 136
sur_2 = 87
sur_3 = 119

per_1 = sur_1/total_p1*100
per_2 = sur_2/total_p2*100
per_3 = sur_3/total_p3*100

print("The Percentage of People who Survived while travelling is Pclass 1 are {}".format(per_1))
print("The Percentage of People who Survived while travelling is Pclass 2 are {}".format(per_2))
print("The Percentage of People who Survived while travelling is Pclass 3 are {}".format(per_3))
# Out:
# The Percentage of People who Survived while travelling is Pclass 1 are 62.96296296296296
# The Percentage of People who Survived while travelling is Pclass 2 are 47.28260869565217
# The Percentage of People who Survived while travelling is Pclass 3 are 24.236252545824847

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observation:

# %% [markdown]
# The people from Pclass 1 were the most survived people followed by Pclass 2 and then Pclass 3

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8c) Create Bar plot for checking the both Survived vs Sex and Sex:Survived or Not. And your Observations?

# %%
#create a subplot
plt.subplot(2,2,1)
a = sns.barplot(data=df,x=df.Sex,y=df.Survived,estimator=sum)
plt.show(a)
# create bar plot using groupby
plt.subplot(2,2,2)
b = df.Survived.groupby(df.Sex).sum().plot(kind='bar')
plt.show(b)
# create count plot
plt.subplot(2,2,3)
c = sns.countplot(data=df, x=df.Survived)
plt.show(c)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101">  Observation:

# %% [markdown]
# As the above plots suggest, females were the ones which survived the most.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.8d) Create Bar plot for checking the following:
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  Number Of Passengers By Pclass &
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  Pclass:Survived vs Dead.

# %%
total_p1 = 216
total_p2 = 184
total_p3 = 491

sur_1 = 136
sur_2 = 87
sur_3 = 119

dead_1 = total_p1-sur_1
dead_2 = total_p2-sur_2
dead_3 = total_p3-sur_3

ls = [dead_1,dead_2,dead_3]
ls
# Out:
# [80, 97, 372]

# %%
df.Survived.groupby(df.Pclass).sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
plt.subplot(2,1,1)
a = sns.countplot(data=df,x=df.Pclass)
plt.show(a)

plt.subplot(2,1,2)
#b = sns.distplot(df.Pclass, ls)
b = df.Survived.groupby(df.Pclass).sum().plot(kind='bar')
plt.show(b)

# %%
#create a subplot
plt.subplot(2,2,1)
a = sns.barplot(data=df,x=df.Pclass,y=df.Survived,estimator=sum)
plt.show(a)
# create bar plot using groupby
plt.subplot(2,2,2)
b = df.Survived.groupby(df.Pclass).sum().plot(kind='bar')
plt.show(b)
# create count plot
plt.subplot(2,2,3)
sns.countplot(data=df, x=df.Survived)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101">  Observation:

# %% [markdown]
# It is evident from the above plots that people from class 1 were the ones who mostly survived.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.8e) Create violinplot plot for checking
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    a) Pclass vs. Age sliced by Survived
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    b) Sex vs Age sliced by Survived. And your Observations?

# %%
# create subplot plot
plt.subplot(2,1,1)

# create violinplot plot using groupby
a = sns.violinplot(data=df, x = df.Pclass, y = df.Age, hue=df.Survived)
plt.show(a)

plt.subplot(2,1,2)
b = sns.violinplot(data=df, x = df.Sex, y = df.Age, hue=df.Survived)
plt.show(b)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %% [markdown]
# Clearly evident that young, females and old aged people could survived majorly.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8f) Create Bar(count) plot for checking the Embarked vs (No. of passengers, sex, Survived , Pclass). And your Observations?

# %%
# create subplot plot

# create Bar (count) plot for Embarked vs. No. Of Passengers Boarded
plt.subplot(2,2,1)
a = sns.countplot(data=df,x = df.Embarked)
plt.show(a)
# create Bar (count) plot for Embarked vs. Male-Female Split
plt.subplot(2,2,2)
b = sns.countplot(data=df, x = df.Sex , hue= df.Embarked)
plt.show(b)
# create Bar (count) plot for Embarked vs Survived
plt.subplot(2,2,3)
c = sns.countplot(data=df, x = df.Survived , hue= df.Embarked)
plt.show(c)
# create Bar (count) plot for Embarked vs Pclass
plt.subplot(2,2,4)
d = sns.countplot(data=df, x = df.Pclass , hue= df.Embarked)
plt.show(d)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %% [markdown]
# High Percentage of people boarded the ship from South Hampton. Also major chunk of people travelled in Pclass 3.

# %% [markdown]
# ### Box Plot
# A box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.8 g)Create a box plot for pclass vs Age. And your Observations?

# %%
sns.boxplot(data=df,x = df.Pclass, y=df.Age)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %% [markdown]
# The median of of people travelling in pclass 1 is higher that suggest more older people travelled in pclass 1 and also youngsters preferred to travel in pclass 3.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.9 Categorical vs. Categorical
#
# * Categorical:

# %% [markdown]
# ### Stacked bar chart

# %% [markdown]
# A stacked bar chart, also known as a stacked bar graph, is a graph that is used to break down and compare parts of a whole. Each bar in the chart represents a whole, and segments in the bar represent different parts or categories of that whole. Different colors are used to illustrate the different categories in the bar.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.9a) Create a Stacked bar chart Sex Vs Survived. And your Observations?

# %%
#create crosstab
ct = pd.crosstab(df.Sex , df.Survived)
ct.plot.bar(stacked=True)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101"> Observations:

# %% [markdown]
# Clearly evident that more females survived as compared to males.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.10 Quantitative vs. Quantitative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
#     Numerical Features: PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.10a) Create a scatter plot for showing age & fare with target varialble. And your Observations?¶

# %%
sns.scatterplot(data=df,x=df.Age,y=df.Fare,hue=df.Survived)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %% [markdown]
# As can be seen, young people who paid less fare, mid aged to old aged people who paid more fares were the ones who mostly survived.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.11 Frequency tables

# %% [markdown]
# 1. One-Way Tables
# 2. Two-Way Tables

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.11 a) Create frequency tables (also known as crosstabs) in pandas using the pd.crosstab() function.

# %%
 # Make a crosstab
# Name the count column
ct = pd.crosstab(df.Survived,columns=df.Survived)
ct.plot.bar(stacked=True)
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Two-Way Tables
#
# Two-way frequency tables, also called contingency tables, are tables of counts with two dimensions where each dimension is a different variable. Two-way tables can give you insight into the relationship between two variables.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.11b )Create Two-way-table for survival vs sex?

# %%
ct = pd.crosstab(df.Sex , df.Survived)
ct.plot.bar(stacked=True)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.12 Check Correlation plot using Headtmap?

# %%
sns.heatmap(df.corr(),cmap='BuPu')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %% [markdown]
# The heatmap shows there was positive correlation between fare and survived.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.12 a) Check the pairplot?

# %%
sns.pairplot(df)
# Out:
# C:\Users\KUS\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\KUS\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#aec101"> Observation:

# %% [markdown]
# As the age increased, fares also increased.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.13 Read the AirPassengers dataset and plot the Seasonality.And your observations?

# %%
#Parse strings to datetime type

#convert from string to datetime

df1 = pd.read_csv("AirPassengers.csv")
df1.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
ls = [d.date() for d in pd.to_datetime(df1.Month)]
ls
# Out:
# [datetime.date(1949, 1, 1),
#  datetime.date(1949, 2, 1),
#  datetime.date(1949, 3, 1),
#  datetime.date(1949, 4, 1),
#  datetime.date(1949, 5, 1),
#  datetime.date(1949, 6, 1),
#  datetime.date(1949, 7, 1),
#  datetime.date(1949, 8, 1),
#  datetime.date(1949, 9, 1),
#  datetime.date(1949, 10, 1),
#  datetime.date(1949, 11, 1),
#  datetime.date(1949, 12, 1),
#  datetime.date(1950, 1, 1),
#  datetime.date(1950, 2, 1),
#  datetime.date(1950, 3, 1),
#  datetime.date(1950, 4, 1),
#  datetime.date(1950, 5, 1),
#  datetime.date(1950, 6, 1),
#  datetime.date(1950, 7, 1),
#  datetime.date(1950, 8, 1),
#  datetime.date(1950, 9, 1),
#  datetime.date(1950, 10, 1),
#  datetime.date(1950, 11, 1),
#  datetime.date(1950, 12, 1),
#  datetime.date(1951, 1, 1),
#  datetime.date(1951, 2, 1),
#  datetime.date(1951, 3, 1),
#  datetime.date(1951, 4, 1),
#  datetime.date(1951, 5, 1),
#  datetime.date(1951, 6, 1),
#  datetime.date(1951, 7, 1),
#  datetime.date(1951, 8, 1),
#  datetime.date(1951, 9, 1),
#  datetime.date(1951, 10, 1),
#  datetime.date(1951, 11, 1),
#  datetime.date(1951, 12, 1),
#  datetime.date(1952, 1, 1),
#  datetime.date(1952, 2, 1),
#  datetime.date(1952, 3, 1),
#  datetime.date(1952, 4, 1),
#  datetime.date(1952, 5, 1),
#  datetime.date(1952, 6, 1),
#  datetime.date(1952, 7, 1),
#  datetime.date(1952, 8, 1),
#  datetime.date(1952, 9, 1),
#  datetime.date(1952, 10, 1),
#  datetime.date(1952, 11, 1),
#  datetime.date(1952, 12, 1),
#  datetime.date(1953, 1, 1),
#  datetime.date(1953, 2, 1),
#  datetime.date(1953, 3, 1),
#  datetime.date(1953, 4, 1),
#  datetime.date(1953, 5, 1),
#  datetime.date(1953, 6, 1),
#  datetime.date(1953, 7, 1),
#  datetime.date(1953, 8, 1),
#  datetime.date(1953, 9, 1),
#  datetime.date(1953, 10, 1),
#  datetime.date(1953, 11, 1),
#  datetime.date(1953, 12, 1),
#  datetime.date(1954, 1, 1),
#  datetime.date(1954, 2, 1),
#  datetime.date(1954, 3, 1),
#  datetime.date(1954, 4, 1),
#  datetime.date(1954, 5, 1),
#  datetime.date(1954, 6, 1),
#  datetime.date(1954, 7, 1),
#  datetime.date(1954, 8, 1),
#  datetime.date(1954, 9, 1),
#  datetime.date(1954, 10, 1),
#  datetime.date(1954, 11, 1),
#  datetime.date(1954, 12, 1),
#  datetime.date(1955, 1, 1),
#  datetime.date(1955, 2, 1),
#  datetime.date(1955, 3, 1),
#  datetime.date(1955, 4, 1),
#  datetime.date(1955, 5, 1),
#  datetime.date(1955, 6, 1),
#  datetime.date(1955, 7, 1),
#  datetime.date(1955, 8, 1),
#  datetime.date(1955, 9, 1),
#  datetime.date(1955, 10, 1),
#  datetime.date(1955, 11, 1),
#  datetime.date(1955, 12, 1),
#  datetime.date(1956, 1, 1),
#  datetime.date(1956, 2, 1),
#  datetime.date(1956, 3, 1),
#  datetime.date(1956, 4, 1),
#  datetime.date(1956, 5, 1),
#  datetime.date(1956, 6, 1),
#  datetime.date(1956, 7, 1),
#  datetime.date(1956, 8, 1),
#  datetime.date(1956, 9, 1),
#  datetime.date(1956, 10, 1),
#  datetime.date(1956, 11, 1),
#  datetime.date(1956, 12, 1),
#  datetime.date(1957, 1, 1),
#  datetime.date(1957, 2, 1),
#  datetime.date(1957, 3, 1),
#  datetime.date(1957, 4, 1),
#  datetime.date(1957, 5, 1),
#  datetime.date(1957, 6, 1),
#  datetime.date(1957, 7, 1),
#  datetime.date(1957, 8, 1),
#  datetime.date(1957, 9, 1),
#  datetime.date(1957, 10, 1),
#  datetime.date(1957, 11, 1),
#  datetime.date(1957, 12, 1),
#  datetime.date(1958, 1, 1),
#  datetime.date(1958, 2, 1),
#  datetime.date(1958, 3, 1),
#  datetime.date(1958, 4, 1),
#  datetime.date(1958, 5, 1),
#  datetime.date(1958, 6, 1),
#  datetime.date(1958, 7, 1),
#  datetime.date(1958, 8, 1),
#  datetime.date(1958, 9, 1),
#  datetime.date(1958, 10, 1),
#  datetime.date(1958, 11, 1),
#  datetime.date(1958, 12, 1),
#  datetime.date(1959, 1, 1),
#  datetime.date(1959, 2, 1),
#  datetime.date(1959, 3, 1),
#  datetime.date(1959, 4, 1),
#  datetime.date(1959, 5, 1),
#  datetime.date(1959, 6, 1),
#  datetime.date(1959, 7, 1),
#  datetime.date(1959, 8, 1),
#  datetime.date(1959, 9, 1),
#  datetime.date(1959, 10, 1),
#  datetime.date(1959, 11, 1),
#  datetime.date(1959, 12, 1),
#  datetime.date(1960, 1, 1),
#  datetime.date(1960, 2, 1),
#  datetime.date(1960, 3, 1),
#  datetime.date(1960, 4, 1),
#  datetime.date(1960, 5, 1),
#  datetime.date(1960, 6, 1),
#  datetime.date(1960, 7, 1),
#  datetime.date(1960, 8, 1),
#  datetime.date(1960, 9, 1),
#  datetime.date(1960, 10, 1),
#  datetime.date(1960, 11, 1),
#  datetime.date(1960, 12, 1)]

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.em;color:#aec101">Observations:

# %% [markdown]
# The month column in df1 has been converted to datetime object.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:##e08484"> THE END
